# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10

# %%
# to improve accuracy
subtract_pixel_mean = True

# %%
n = 3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# using resnet v1
model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 16)   448         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 32, 32, 16)   64          conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 16)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 16)   2320        activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 16)   64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 16)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 16)   2320        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 16)   64          conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 16)   0           activation_39[0][0]
#                                                                  batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 16)   0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 16)   2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 32, 32, 16)   64          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 16)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 16)   2320        activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 32, 16)   64          conv2d_47[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 16)   0           activation_41[0][0]
#                                                                  batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 16)   0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 16)   2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 32, 32, 16)   64          conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 32, 16)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 16)   2320        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 32, 32, 16)   64          conv2d_49[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 32, 32, 16)   0           activation_43[0][0]
#                                                                  batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 16)   0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 32)   4640        activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 16, 16, 32)   128         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 16, 16, 32)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 16, 16, 32)   9248        activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 16, 16, 32)   544         activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 16, 16, 32)   128         conv2d_51[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 16, 16, 32)   0           conv2d_52[0][0]
#                                                                  batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 32)   0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 16, 16, 32)   9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 16, 32)   128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 16, 16, 32)   9248        activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 16, 16, 32)   128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 32)   0           activation_47[0][0]
#                                                                  batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 32)   0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 16, 16, 32)   9248        activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 16, 16, 32)   128         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 16, 16, 32)   9248        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 16, 16, 32)   128         conv2d_56[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 16, 16, 32)   0           activation_49[0][0]
#                                                                  batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 16, 16, 32)   0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 8, 8, 64)     18496       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 64)     256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 64)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 8, 8, 64)     36928       activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 8, 8, 64)     2112        activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8, 8, 64)     256         conv2d_58[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 8, 8, 64)     0           conv2d_59[0][0]
#                                                                  batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 64)     0           add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 8, 8, 64)     36928       activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8, 8, 64)     256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8, 8, 64)     0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 8, 8, 64)     36928       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8, 8, 64)     256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 8, 8, 64)     0           activation_53[0][0]
#                                                                  batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8, 8, 64)     0           add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 8, 8, 64)     36928       activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 8, 8, 64)     256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8, 8, 64)     0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 8, 8, 64)     36928       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 8, 8, 64)     256         conv2d_63[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 8, 8, 64)     0           activation_55[0][0]
#                                                                  batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 8, 8, 64)     0           add_27[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 64)     0           activation_57[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 64)           0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           650         flatten_3[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
# Epoch 1/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 97s 62ms/step - loss: 1.5715 - acc: 0.4868 - val_loss: 1.8229 - val_acc: 0.4678
#
# Epoch 00001: val_acc improved from -inf to 0.46780, saving model to /content/saved_models/cifar10_ResNet20v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 60ms/step - loss: 1.1804 - acc: 0.6374 - val_loss: 1.3115 - val_acc: 0.6210
#
# Epoch 00002: val_acc improved from 0.46780 to 0.62100, saving model to /content/saved_models/cifar10_ResNet20v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 60ms/step - loss: 1.0169 - acc: 0.7027 - val_loss: 1.0131 - val_acc: 0.7085
#
# Epoch 00003: val_acc improved from 0.62100 to 0.70850, saving model to /content/saved_models/cifar10_ResNet20v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 91s 58ms/step - loss: 0.9239 - acc: 0.7374 - val_loss: 1.1278 - val_acc: 0.6767
#
# Epoch 00004: val_acc did not improve from 0.70850
# Epoch 5/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 91s 58ms/step - loss: 0.8601 - acc: 0.7590 - val_loss: 1.3467 - val_acc: 0.6414
#
# Epoch 00005: val_acc did not improve from 0.70850
# Epoch 6/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 91s 58ms/step - loss: 0.8161 - acc: 0.7792 - val_loss: 0.9459 - val_acc: 0.7460
#
# Epoch 00006: val_acc improved from 0.70850 to 0.74600, saving model to /content/saved_models/cifar10_ResNet20v1_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.7809 - acc: 0.7920 - val_loss: 0.9682 - val_acc: 0.7331
#
# Epoch 00007: val_acc did not improve from 0.74600
# Epoch 8/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.7517 - acc: 0.8029 - val_loss: 0.9457 - val_acc: 0.7493
#
# Epoch 00008: val_acc improved from 0.74600 to 0.74930, saving model to /content/saved_models/cifar10_ResNet20v1_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.7280 - acc: 0.8128 - val_loss: 0.9619 - val_acc: 0.7402
#
# Epoch 00009: val_acc did not improve from 0.74930
# Epoch 10/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.7099 - acc: 0.8195 - val_loss: 0.8225 - val_acc: 0.7858
#
# Epoch 00010: val_acc improved from 0.74930 to 0.78580, saving model to /content/saved_models/cifar10_ResNet20v1_model.010.h5
# Epoch 11/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.6878 - acc: 0.8269 - val_loss: 0.8009 - val_acc: 0.7982
#
# Epoch 00011: val_acc improved from 0.78580 to 0.79820, saving model to /content/saved_models/cifar10_ResNet20v1_model.011.h5
# Epoch 12/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.6783 - acc: 0.8317 - val_loss: 1.1821 - val_acc: 0.6969
#
# Epoch 00012: val_acc did not improve from 0.79820
# Epoch 13/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.6651 - acc: 0.8367 - val_loss: 0.7504 - val_acc: 0.8138
#
# Epoch 00013: val_acc improved from 0.79820 to 0.81380, saving model to /content/saved_models/cifar10_ResNet20v1_model.013.h5
# Epoch 14/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.6586 - acc: 0.8398 - val_loss: 0.9442 - val_acc: 0.7575
#
# Epoch 00014: val_acc did not improve from 0.81380
# Epoch 15/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.6495 - acc: 0.8437 - val_loss: 0.7885 - val_acc: 0.8034
#
# Epoch 00015: val_acc did not improve from 0.81380
# Epoch 16/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.6332 - acc: 0.8477 - val_loss: 0.7428 - val_acc: 0.8146
#
# Epoch 00016: val_acc improved from 0.81380 to 0.81460, saving model to /content/saved_models/cifar10_ResNet20v1_model.016.h5
# Epoch 17/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.6331 - acc: 0.8488 - val_loss: 0.8471 - val_acc: 0.7904
#
# Epoch 00017: val_acc did not improve from 0.81460
# Epoch 18/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.6183 - acc: 0.8541 - val_loss: 0.8119 - val_acc: 0.8102
#
# Epoch 00018: val_acc did not improve from 0.81460
# Epoch 19/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.6111 - acc: 0.8570 - val_loss: 0.7915 - val_acc: 0.8015
#
# Epoch 00019: val_acc did not improve from 0.81460
# Epoch 20/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.6067 - acc: 0.8590 - val_loss: 0.8958 - val_acc: 0.7755
#
# Epoch 00020: val_acc did not improve from 0.81460
# Epoch 21/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.6033 - acc: 0.8615 - val_loss: 0.7649 - val_acc: 0.8143
#
# Epoch 00021: val_acc did not improve from 0.81460
# Epoch 22/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.5991 - acc: 0.8622 - val_loss: 0.9030 - val_acc: 0.7851
#
# Epoch 00022: val_acc did not improve from 0.81460
# Epoch 23/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.5940 - acc: 0.8649 - val_loss: 0.8521 - val_acc: 0.7987
#
# Epoch 00023: val_acc did not improve from 0.81460
# Epoch 24/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.5862 - acc: 0.8683 - val_loss: 0.7154 - val_acc: 0.8269
#
# Epoch 00024: val_acc improved from 0.81460 to 0.82690, saving model to /content/saved_models/cifar10_ResNet20v1_model.024.h5
# Epoch 25/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.5867 - acc: 0.8686 - val_loss: 0.8364 - val_acc: 0.7972
#
# Epoch 00025: val_acc did not improve from 0.82690
# Epoch 26/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.5781 - acc: 0.8699 - val_loss: 0.7275 - val_acc: 0.8273
#
# Epoch 00026: val_acc improved from 0.82690 to 0.82730, saving model to /content/saved_models/cifar10_ResNet20v1_model.026.h5
# Epoch 27/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.5745 - acc: 0.8711 - val_loss: 0.7756 - val_acc: 0.8175
#
# Epoch 00027: val_acc did not improve from 0.82730
# Epoch 28/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.5699 - acc: 0.8712 - val_loss: 0.6662 - val_acc: 0.8462
#
# Epoch 00028: val_acc improved from 0.82730 to 0.84620, saving model to /content/saved_models/cifar10_ResNet20v1_model.028.h5
# Epoch 29/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.5637 - acc: 0.8756 - val_loss: 0.7159 - val_acc: 0.8297
#
# Epoch 00029: val_acc did not improve from 0.84620
# Epoch 30/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.5661 - acc: 0.8755 - val_loss: 0.7463 - val_acc: 0.8192
#
# Epoch 00030: val_acc did not improve from 0.84620
# Epoch 31/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.5654 - acc: 0.8755 - val_loss: 0.7589 - val_acc: 0.8247
#
# Epoch 00031: val_acc did not improve from 0.84620
# Epoch 32/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.5609 - acc: 0.8776 - val_loss: 0.6809 - val_acc: 0.8412
#
# Epoch 00032: val_acc did not improve from 0.84620
# Epoch 33/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.5582 - acc: 0.8765 - val_loss: 0.7623 - val_acc: 0.8153
#
# Epoch 00033: val_acc did not improve from 0.84620
# Epoch 34/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 96s 62ms/step - loss: 0.5586 - acc: 0.8776 - val_loss: 0.7061 - val_acc: 0.8391
#
# Epoch 00034: val_acc did not improve from 0.84620
# Epoch 35/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.5533 - acc: 0.8801 - val_loss: 0.6822 - val_acc: 0.8426
#
# Epoch 00035: val_acc did not improve from 0.84620
# Epoch 36/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 96s 61ms/step - loss: 0.5472 - acc: 0.8831 - val_loss: 0.6780 - val_acc: 0.8446
#
# Epoch 00036: val_acc did not improve from 0.84620
# Epoch 37/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.5490 - acc: 0.8810 - val_loss: 0.8565 - val_acc: 0.7972
#
# Epoch 00037: val_acc did not improve from 0.84620
# Epoch 38/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 96s 61ms/step - loss: 0.5452 - acc: 0.8839 - val_loss: 0.7898 - val_acc: 0.8117
#
# Epoch 00038: val_acc did not improve from 0.84620
# Epoch 39/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.5452 - acc: 0.8846 - val_loss: 0.6998 - val_acc: 0.8397
#
# Epoch 00039: val_acc did not improve from 0.84620
# Epoch 40/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.5432 - acc: 0.8851 - val_loss: 0.7294 - val_acc: 0.8338
#
# Epoch 00040: val_acc did not improve from 0.84620
# Epoch 41/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 90s 58ms/step - loss: 0.5409 - acc: 0.8838 - val_loss: 0.7321 - val_acc: 0.8265
#
# Epoch 00041: val_acc did not improve from 0.84620
# Epoch 42/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 86s 55ms/step - loss: 0.5378 - acc: 0.8857 - val_loss: 0.7210 - val_acc: 0.8328
#
# Epoch 00042: val_acc did not improve from 0.84620
# Epoch 43/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 88s 56ms/step - loss: 0.5379 - acc: 0.8863 - val_loss: 0.6430 - val_acc: 0.8528
#
# Epoch 00043: val_acc improved from 0.84620 to 0.85280, saving model to /content/saved_models/cifar10_ResNet20v1_model.043.h5
# Epoch 44/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 90s 58ms/step - loss: 0.5352 - acc: 0.8872 - val_loss: 0.6321 - val_acc: 0.8599
#
# Epoch 00044: val_acc improved from 0.85280 to 0.85990, saving model to /content/saved_models/cifar10_ResNet20v1_model.044.h5
# Epoch 45/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 96s 61ms/step - loss: 0.5367 - acc: 0.8865 - val_loss: 0.7803 - val_acc: 0.8193
#
# Epoch 00045: val_acc did not improve from 0.85990
# Epoch 46/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 96s 62ms/step - loss: 0.5286 - acc: 0.8907 - val_loss: 0.6602 - val_acc: 0.8454
#
# Epoch 00046: val_acc did not improve from 0.85990
# Epoch 47/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 96s 61ms/step - loss: 0.5293 - acc: 0.8895 - val_loss: 0.7272 - val_acc: 0.8372
#
# Epoch 00047: val_acc did not improve from 0.85990
# Epoch 48/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.5239 - acc: 0.8904 - val_loss: 0.7887 - val_acc: 0.8227
#
# Epoch 00048: val_acc did not improve from 0.85990
# Epoch 49/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 96s 61ms/step - loss: 0.5272 - acc: 0.8899 - val_loss: 0.7283 - val_acc: 0.8286
#
# Epoch 00049: val_acc did not improve from 0.85990
# Epoch 50/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 96s 62ms/step - loss: 0.5240 - acc: 0.8913 - val_loss: 0.7670 - val_acc: 0.8208
#
# Epoch 00050: val_acc did not improve from 0.85990
# 10000/10000 [==============================] - 3s 346us/step
# Test loss: 0.766970258140564
# Test accuracy: 0.8208
